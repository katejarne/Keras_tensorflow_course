# %%
#Xor task with keras (Toy Task)

# %%
#We import libraries
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
#We prepare the training Data

# the four different states of the XOR gate
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")

# the four expected results in the same order
target_data = np.array([[0],[1],[1],[0]], "float32")

# %%
#We generate and compile the model
model = Sequential()
#model.add(Dense(units=16,  input_shape=(None, 2), activation='relu'))
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['binary_accuracy'])
#model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#We train the model
#history = model.fit(training_data, target_data, nb_epoch=500, verbose=2)
history =  model.fit(training_data, target_data, epochs=500,  verbose=2, validation_split=0.2, shuffle=True)
# Out:
# Train on 3 samples, validate on 1 samples
# Epoch 1/500
#  - 0s - loss: 0.2109 - binary_accuracy: 1.0000 - val_loss: 0.3409 - val_binary_accuracy: 0.0000e+00
# Epoch 2/500
#  - 0s - loss: 0.2105 - binary_accuracy: 0.6667 - val_loss: 0.3423 - val_binary_accuracy: 0.0000e+00
# Epoch 3/500
#  - 0s - loss: 0.2100 - binary_accuracy: 0.6667 - val_loss: 0.3436 - val_binary_accuracy: 0.0000e+00
# Epoch 4/500
#  - 0s - loss: 0.2096 - binary_accuracy: 0.6667 - val_loss: 0.3449 - val_binary_accuracy: 0.0000e+00
# Epoch 5/500
#  - 0s - loss: 0.2091 - binary_accuracy: 0.6667 - val_loss: 0.3462 - val_binary_accuracy: 0.0000e+00
# Epoch 6/500
#  - 0s - loss: 0.2087 - binary_accuracy: 0.6667 - val_loss: 0.3474 - val_binary_accuracy: 0.0000e+00
# Epoch 7/500
#  - 0s - loss: 0.2082 - binary_accuracy: 0.6667 - val_loss: 0.3486 - val_binary_accuracy: 0.0000e+00
# Epoch 8/500
#  - 0s - loss: 0.2078 - binary_accuracy: 0.6667 - val_loss: 0.3498 - val_binary_accuracy: 0.0000e+00
# Epoch 9/500
# ...

# %%
#We test the model

model.test_on_batch(training_data, target_data)
model.metrics_names

print ("training_data\n ",training_data )
print ("target_data\n ",target_data)
print ("model prediction\n ", model.predict(training_data))#.round()

print(history.history.keys())
#  "Accuracy"
#plt.plot(history.history['val_binary_accuracy'])
#plt.plot(history.history['binary_accuracy'])
#plt.title('model accuracy')
#plt.ylabel('accuracy')
plt.xlabel('epoch')
#plt.legend(['val_binary_accuracy', 'binary_accuracy'], loc='upper left')

# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')

plt.show()
# Out:
# training_data
#   [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# target_data
#   [[0.]
#  [1.]
#  [1.]
#  [0.]]
# model prediction
#   [[0.4343114 ]
#  [0.859429  ]
#  [0.85045576]
#  [0.91895425]]
# dict_keys(['val_loss', 'val_binary_accuracy', 'loss', 'binary_accuracy'])
